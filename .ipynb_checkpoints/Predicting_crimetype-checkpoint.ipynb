# %%
#Importing required modules

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split  
from sklearn import tree, metrics



df= pd.read_csv('D:/1081ML/1081MLMID1/Chicago_crime.csv') # Loading dataser

# %%
#Visualizing crime type and its frequency

b=df['Primary Type'].value_counts().head(10)
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.gca() 
b.plot.bar(ax = ax) 
ax.set_title('Crime Type by frequency')
ax.set_xlabel('Crime type')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Visualizing location type and its frequency

b=df['Location Description'].value_counts().head(10)
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.gca() 
b.plot.bar(ax = ax) 
ax.set_title('Location Type by Frequency')
ax.set_xlabel('Location')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Visualizing crime description and its frequency

c=df['Description'].value_counts().head(20)

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,10))
ax = fig.gca() 
c.plot.bar(ax = ax) 
ax.set_title('Crime Type by Frequency')
ax.set_xlabel('Crime Description')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Some exploratory data analysis

aa=df[['Primary Type','Description']]
bb=aa.groupby(['Description']).count()
bb
# Out:
#                                                     Primary Type
# Description
# $300 AND UNDER                                                15
# $500 AND UNDER                                            554442
# ABUSE/NEGLECT: CARE FACILITY                                 116
# ADULTRY                                                        6
# AGG CRIM SEX ABUSE FAM MEMBER                               3342
# AGG CRIMINAL SEXUAL ABUSE                                   5666
# AGG PO HANDS ETC SERIOUS INJ                                 465
# AGG PO HANDS NO/MIN INJURY                                 19680
# AGG PRO EMP HANDS SERIOUS INJ                                471
# AGG PRO.EMP: HANDGUN                                         482
# AGG PRO.EMP: OTHER DANG WEAPON                              2484
# AGG PRO.EMP: OTHER FIREARM                                   112
# AGG PRO.EMP:KNIFE/CUTTING INST                               685
# AGG RIT MUT: HANDS/FIST/FEET NO/MINOR INJURY                   3
# AGG RIT MUT: HANDS/FIST/FEET SERIOUS INJURY                    5
# AGG RITUAL MUT:HANDGUN                                         5
# AGG RITUAL MUT:KNIFE/CUTTING I                                 5
# AGG RITUAL MUT:OTH DANG WEAPON                                 5
# AGG SEX ASSLT OF CHILD FAM MBR                              2895
# AGG: FINANCIAL ID THEFT                                     2901
# AGG: HANDS/FIST/FEET NO/MINOR INJURY                        4990
# AGG: HANDS/FIST/FEET SERIOUS INJURY                         2364
# AGGRAVATED                                                 15386
# AGGRAVATED COMPUTER TAMPERING                                 23
# AGGRAVATED DOMESTIC BATTERY                                 1546
# AGGRAVATED DOMESTIC BATTERY: HANDGUN                         357
# AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET SE...          3719
# AGGRAVATED DOMESTIC BATTERY: KNIFE/CUTTING INST            12786
# AGGRAVATED DOMESTIC BATTERY: OTHER DANG WEAPON             18600
# AGGRAVATED DOMESTIC BATTERY: OTHER FIREARM                   136
# ...                                                          ...
# UNLAWFUL POSS AMMUNITION                                    1515
# UNLAWFUL POSS OF HANDGUN                                   48272
# UNLAWFUL POSS OTHER FIREARM                                 2763
# UNLAWFUL RESTRAINT                                          1092
# UNLAWFUL SALE HANDGUN                                        223
# UNLAWFUL SALE OTHER FIREARM                                   87
# UNLAWFUL SALE/DELIVERY OF FIREARM AT SCHOOL                  153
# UNLAWFUL USE HANDGUN                                        3455
# UNLAWFUL USE OF A COMPUTER                                   451
# UNLAWFUL USE OF BODY ARMOR                                     8
# UNLAWFUL USE OF RECORDED SOUND                              1400
# UNLAWFUL USE OTHER DANG WEAPON                              8506
# UNLAWFUL USE OTHER FIREARM                                   589
# UNLAWFUL USE/SALE AIR RIFLE                                 2422
# USE OF METAL PIERCING BULLETS                                  4
# VEHICLE TITLE/REG OFFENSE                                   7796
# VEHICULAR HIJACKING                                         5107
# VIO BAIL BOND: DOM VIOLENCE                                  648
# VIOL CHARITABLE GAME ACT                                      16
# VIOLATE ORDER OF PROTECTION                                34118
# VIOLATION GPS MONITORING DEVICE                               62
# VIOLATION OF CIVIL NO CONTACT ORDER                          321
# VIOLATION OF SMOKING BAN                                      39
# VIOLATION OF STALKING NO CONTACT ORDER                       168
# VIOLATION OF SUMMARY CLOSURE                                   5
# VIOLENT OFFENDER: ANNUAL REGISTRATION                        189
# VIOLENT OFFENDER: DUTY TO REGISTER                            94
# VIOLENT OFFENDER: FAIL TO REGISTER NEW ADDRESS                43
# WIREROOM/HORSES                                               21
# WIREROOM/SPORTS                                               64
#
# [380 rows x 1 columns]

# %%
#Dropping rows with missing values

df=df.dropna()

# %%
#Checking to see if there's any missing values still

df.isnull().sum()
# Out:
# ID                      0
# Case Number             0
# Date                    0
# Block                   0
# IUCR                    0
# Primary Type            0
# Description             0
# Location Description    0
# Arrest                  0
# Domestic                0
# Beat                    0
# District                0
# Ward                    0
# Community Area          0
# FBI Code                0
# X Coordinate            0
# Y Coordinate            0
# Year                    0
# Updated On              0
# Latitude                0
# Longitude               0
# Location                0
# dtype: int64

# %%
#Correcting the data types of the columns

df["Location"] = df["Location"].astype('category')
df["Location"] = df["Location"].cat.codes
df["Block"] = df["Block"].astype('category')
df["Block"] = df["Block"].cat.codes
df["Primary Type"] = df["Primary Type"].astype('category')
df["Primary Type"] = df["Primary Type"].cat.codes
df["Community Area"] = df["Community Area"].astype('category')
df["Community Area"] = df["Community Area"].cat.codes;

# %%
#Proper date formatting

df.Date=pd.to_datetime(df.Date, format= '%m/%d/%Y %I:%M:%S %p')
df.index=pd.DatetimeIndex(df.Date)
df['Hour']=df['Date'].apply(lambda x: x.hour)
df['Month']=df['Date'].apply(lambda x: x.month)

# %%
# Choosing location based features for the model

df_imp_features=df[['Block',
'Location', 'District', 'Community Area', 'X Coordinate', 'Y Coordinate', 'Latitude' , 'Longitude', 'Hour','Month','Primary Type']]

# %%
#Reseting the index

df_imp_features=df_imp_features.reset_index()

# %%
#Separating predictive variables with target variable. Also, removing date from our predictive variable.

X = df_imp_features.loc[:,df_imp_features.columns != 'Primary Type']
X = df_imp_features.loc[:,df_imp_features.columns != 'Date']

y = df_imp_features['Primary Type']

# %%
# Splitting our dataset with training size of 80% and testing size of 20%

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)

# %%
# Choosing decision tree for the model and fitting the model.

dtree = tree.DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)
dtree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=3,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
y_pred = dtree.predict(X_test)

# %%
# Checking the accuracy score

accuracy = metrics.accuracy_score(y_test, y_pred)
print('Accuracy: {:.2f}'.format(accuracy))
# Out:
# Accuracy: 0.81
